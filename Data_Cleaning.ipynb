# %%
# import libraries

import pandas as pd

# %%
df = pd.read_csv('kept_columns.csv')
df.head()
# Out:
#    ABSOLUTE_Ploidy  ABSOLUTE_Purity Canonical_mut_in_KRAS_EGFR_ALK  \
# 0              NaN              NaN                            NaN
# 1             3.77             0.46                              Y
# 2              NaN              NaN                            NaN
# 3              NaN              NaN                              N
# 4             2.04             0.48                              N
#
#   Cnncl_mt_n_KRAS_EGFR_ALK_RET_ROS1_BRAF_ERBB2_HRAS_NRAS_AKT1_MAP2  \
# 0                                                NaN
# 1                                                  Y
# 2                                                NaN
# 3                                                  N
# 4                                                  N
#
#    Estimated_allele_fraction_of_a_clonal_varnt_prsnt_t_1_cpy_pr_cll  \
# 0                                                NaN
# 1                                               0.16
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1299 entries, 0 to 1298
# Data columns (total 47 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   ABSOLUTE_Ploidy                                                   222 non-null    float64
#  1   ABSOLUTE_Purity                                                   222 non-null    float64
#  2   Canonical_mut_in_KRAS_EGFR_ALK                                    298 non-null    object
#  3   Cnncl_mt_n_KRAS_EGFR_ALK_RET_ROS1_BRAF_ERBB2_HRAS_NRAS_AKT1_MAP2  298 non-null    object
#  4   Estimated_allele_fraction_of_a_clonal_varnt_prsnt_t_1_cpy_pr_cll  222 non-null    float64
#  5   Expression_Subtype                                                298 non-null    object
#  6   Pathology_Updated                                                 295 non-null    object
# ...

# %%
# df.drop(["additional_pharmaceutical_therapy"], axis = 1)
# df.head()

#,'additional_radiation_therapy','additional_surgery_locoregional_procedure','additional_surgery_metastatic_procedure'

# %%
"""
Categorical  to float 
(Yes/No): (0/1)
2,3,20,22,25,32,34,36,39,40,41,44

(x,y,z): (0/1/2)
5,18,21

(x,y,z,a): (0/1/2/3)
33,35

(x,y,z,a,b): (0/1/2/3/4)
6,14,24,31

change 21 yes, pharma... to YES only
change[discrepency] to blanks: 32,33,34

"""

# %%
"""
Drop columns
8,9,10,11,12,13,19,[27:30],38,43,45,46
"""
